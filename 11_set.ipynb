# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.barplot(x=['A','B','C'], y=[1,2,4])
plt.show()

# %%
sns.set(style='darkgrid', palette='dark', font='Verdana', font_scale=1)
sns.barplot(x=['A','B','C'], y=[1,7.5,4.1])
plt.show()
